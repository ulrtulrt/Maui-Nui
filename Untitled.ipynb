# %%
import pandas as pd

import matplotlib.pyplot as plt

import seaborn as sns


Food_Shortage = pd.read_csv('???? Food_Insecurity_Index_Maui.csv')


sns.set(style="whitegrid", color_codes=TRUE)


plt.title('Maui Food Shortage by Zipcode', fontsize=20)


sns.countplot(x="Zip Code", color="b", data=Food_Shortage);


plt.savefig("verticalbarchart.png")


plt.show()
